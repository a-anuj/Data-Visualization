# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'
df = pd.read_csv(url)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(df["sepal_width"][:30])
plt.show()

# %%
plt.plot(df["sepal_length"][:50], linestyle="-",color="red",marker="s")

# %%
plt.plot(df["petal_length"][:50],linestyle="-", marker="o", color="green")
plt.xlim(1.2,5.2)
plt.ylim(1.2,5.2)
plt.xticks([1,1.5,2,2.5,3,3.5,4,4.5,5])
plt.yticks([1,1.5,2,2.5,3,3.5,4,4.5,5])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("This is a title ($cm$)")
plt.show()

# %%
import numpy as np
print(np.linspace(0,10,100))
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]

# %%
x = np.arange(1,11,1)
y = x**2
plt.plot(x, color="green")
plt.plot(y,color="blue")
plt.annotate("Square function",xy=[6,50],xytext=[5,75],arrowprops=dict(facecolor="red",shrink=0))
plt.annotate("Constant function",xy=[6,10],xytext=[5,20],arrowprops=dict(facecolor="red",shrink=0))
# Out:
# Text(5, 20, 'Constant function')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
fig,axes = plt.subplots(2,2,figsize=(10,12))

sc1 = axes[0,0].scatter(df['petal_length'],df["petal_width"], c=df["petal_length"], cmap="viridis")
plt.colorbar(sc1,ax=axes[0,0],label="Petal length")

sc2 = axes[0,1].scatter(df["sepal_length"],df["sepal_width"], c=df["sepal_length"])
plt.colorbar(sc2,ax=axes[0,1])

# %%
fig,axes = plt.subplots(2,2,figsize=(10,12))

sc1 = axes[0,0].scatter(df["sepal_length"],df["sepal_width"],c=df["petal_length"],cmap="viridis")
plt.colorbar(sc1,ax=axes[0,0],label="Petal Length (cm)")
axes[0,0].set_title("Sepal Length vs Sepal Width")
axes[0,0].set_xlim(3,7)
axes[0,0].set_ylim(3,5)
axes[0,0].set_xticks([3,3.5,4,4.5,5,5.5,6,6.5,7])
axes[0,0].set_yticks([3,3.5,4,4.5,5])
axes[0,0].annotate("Sepal Length (vs) Sepal Width",xy=(5.6,4.4),xytext=(4,4.7),arrowprops=dict(facecolor="red"))
axes[0,0].set_xlabel("Sepal Length")
axes[0,0].set_ylabel("Sepal Width")


sc2 = axes[0,1].plot(df["sepal_length"][:20],linestyle="-",color="red",marker="o")
axes[0,1].annotate("Peak",xy=(5,5.4),xytext=(5.9,5.7),arrowprops=dict(facecolor="green"))

plt.tight_layout()
plt.show()

# %%
from scipy.stats import gaussian_kde
import numpy as np

# %%
data = df["petal_length"]
kde = gaussian_kde(data)

x = np.linspace(data.min(),data.max(),100)

plt.plot(x,kde(x),color="green")
plt.show()

# %%
x = df["sepal_length"]
y = df["sepal_width"]

xy = np.vstack([x,y])
kde = gaussian_kde(xy)

xi,yi = np.mgrid[x.min():x.max():100j,y.min():y.max():100j]
zi = kde(np.vstack([xi.flatten(),yi.flatten()]))

plt.pcolormesh(xi,yi,zi.reshape(xi.shape),shading="auto",cmap="Blues")
plt.contour(xi,yi,zi.reshape(xi.shape),color="k")

plt.show()
# Out:
# /tmp/ipykernel_21995/1201997749.py:11: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(xi,yi,zi.reshape(xi.shape),color="k")

# %%
x1 = np.array([1,3,5,7,9])
y1 = np.array([2,4,6,8,10])

plt.bar(x1,x1**2)
plt.bar(y1,y1**2)

for x,y in zip(x1,x1**2):
    plt.text(x,y+0.5,'%d' % y)

for x,y in zip(y1,y1**2):
    plt.text(x,y+0.5,'%d' % y)

# %%
x = ["A","B","C"]
y1 = [10,20,30]
y2 = [5,5,5]
y3 = [2,2,2]

plt.bar(x,y1,width=0.5)
plt.bar(x,y2,bottom=y1,width=0.5)
plt.bar(x,y3,bottom=np.add(y1,y2),width=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
x1 = ["A","B","C"]
y1 = [10,20,30]
y2 = [15,35,25]
y3 = [32,22,12]

pos1 = np.arange(len(y1))
pos2 = [x+0.25 for x in pos1]
pos3 = [x+0.25 for x in pos2]
    
plt.bar(pos1,y1,width=0.25)
plt.bar(pos2,y2,width=0.25)
plt.bar(pos3,y3,width=0.25)

plt.xticks([x+0.25 for x in pos1],x1)
# Out:
# ([<matplotlib.axis.XTick at 0x7a80f84d75f0>,
#   <matplotlib.axis.XTick at 0x7a80f83335f0>,
#   <matplotlib.axis.XTick at 0x7a80f878d340>],
#  [Text(0.25, 0, 'A'), Text(1.25, 0, 'B'), Text(2.25, 0, 'C')])

# %%
plt.scatter(np.random.random(10),np.random.random(10),c="blue",alpha=0.5,s=100)

# %%
plt.pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a811246d460>,
#   <matplotlib.patches.Wedge at 0x7a810b78d070>,
#   <matplotlib.patches.Wedge at 0x7a80ed5d4c20>,
#   <matplotlib.patches.Wedge at 0x7a80ed40e390>],
#  [Text(0.8706461467870358, 0.6722910731854822, 'A'),
#   Text(-0.9592543184808255, 0.5383596868970475, 'B'),
#   Text(0.12030828398170017, -1.0934010777410907, 'C'),
#   Text(1.244880780288671, -0.3745288278195283, 'D')],
#  [Text(0.474897898247474, 0.36670422173753575, '20.9'),
#   Text(-0.5232296282622685, 0.2936507383074804, '41.9'),
#   Text(0.06562270035365463, -0.5964005878587767, '27.9'),
#   Text(0.7660804801776435, -0.2304792786581712, '9.3')])

# %%
fig,axes = plt.subplots(2,3,figsize=(10,6))
axes[0,0].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[0,1].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[0,2].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[1,0].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[1,1].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[1,2].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7a80ed214140>,
#   <matplotlib.patches.Wedge at 0x7a81089724b0>,
#   <matplotlib.patches.Wedge at 0x7a80ed255130>,
#   <matplotlib.patches.Wedge at 0x7a80ed255940>],
#  [Text(0.8706461467870358, 0.6722910731854822, 'A'),
#   Text(-0.9592543184808255, 0.5383596868970475, 'B'),
#   Text(0.12030828398170017, -1.0934010777410907, 'C'),
#   Text(1.244880780288671, -0.3745288278195283, 'D')],
#  [Text(0.474897898247474, 0.36670422173753575, '20.9'),
#   Text(-0.5232296282622685, 0.2936507383074804, '41.9'),
#   Text(0.06562270035365463, -0.5964005878587767, '27.9'),
#   Text(0.7660804801776435, -0.2304792786581712, '9.3')])

# %%
import seaborn as sns

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x1 = np.linspace(0, 10, 1000)
y1 = np.sin(x1)

sns.set(rc={"axes.facecolor":"yellow","xtick.labelsize":14})

plt.style.use("ggplot")
sns.lineplot(x=x1, y=y1)
plt.xlim(0,10)
plt.yticks([-1,0,1])
plt.grid(True)
plt.show()

# %%
spotify = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/spotify.csv', index_col='Date')
spotify.sample(10)
# Out:
#             Shape of You   Despacito  Something Just Like This     HUMBLE.  \
# Date
# 2017-02-12      13676618   7104062.0                       NaN         NaN
# 2017-02-19      13745624   6856240.0                       NaN         NaN
# 2017-09-17       4217726   6217801.0                 2411478.0   3022022.0
# 2017-04-20      10826572  15603034.0                 7578070.0  11181908.0
# 2017-05-14       8671832  18556585.0                 5758414.0   7511379.0
# 2017-03-24      14738207   6914549.0                 8016284.0         NaN
# 2018-01-01       4865387   5557165.0                 2179506.0   2368321.0
# 2018-01-03       4596993   3890385.0                 2363422.0   2587620.0
# 2017-04-29      10836688  20266973.0                 7228232.0   9535829.0
# 2017-02-03      15746115   7783608.0                       NaN         NaN
#
#             Unforgettable
# Date
# 2017-02-12            NaN
# 2017-02-19            NaN
# 2017-09-17      5050812.0
# 2017-04-20      1820033.0
# 2017-05-14      3845575.0
# 2017-03-24            NaN
# 2018-01-01      2537274.0
# 2018-01-03      2753557.0
# 2017-04-29      3191729.0
# 2017-02-03            NaN

# %%
sns.lineplot(data=spotify)
plt.rcParams["text.color"] = "black"

# %%
employment = pd.read_excel('https://github.com/dayanandv/Data-Science/raw/main/dataset/unemployment.xlsx')
employment.head()
# Out:
#               Age Gender     Period  Unemployed
# 0  16 to 19 years    Men 2005-01-01       91000
# 1  20 to 24 years    Men 2005-01-01      175000
# 2  25 to 34 years    Men 2005-01-01      194000
# 3  35 to 44 years    Men 2005-01-01      201000
# 4  45 to 54 years    Men 2005-01-01      207000

# %%
#sns.set(rc={"axes.labelsize":24,"xtick.labelsize":20,"ytick.labelsize":20,"legend.fontsize":24,"legend.title_fontsize":24})
plt.figure(figsize=(30,15))
sns.lineplot(x="Period",y="Unemployed",hue="Gender",data=employment)
# Out:
# <Axes: xlabel='Period', ylabel='Unemployed'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.random.normal(1,10,1000)
import seaborn as sns
sns.histplot(x,bins=30,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
from scipy.stats import gaussian_kde

# %%
url = 'https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'
df = pd.read_csv(url)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data = df["petal_length"]

x = np.linspace(data.min(),data.max(),100)
kde = gaussian_kde(data)

plt.plot(x,kde(x))

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data = df.corr(numeric_only=True)
sns.heatmap(data,center=0,annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(
    vars=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    data=iris,
    hue="species"
)

# %%
iris_corr = iris.corr(numeric_only=True)
sns.heatmap(iris_corr,annot=True)
# Out:
# <Axes: >

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(
    x="day",
    y="tip",
    hue="sex",
    data=tips,
    kind="box"
)

# %%
sns.histplot(
    x = "total_bill",
    hue="smoker",
    data=tips,
    kde=True,
    multiple="stack"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.scatterplot(
    x="total_bill",
    y="tip",
    data=tips,
    hue="time",
    size="size",
    alpha=0.7
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
fig,axes = plt.subplots(1,3,figsize=(30,9))

iris_corr = iris.corr(numeric_only=True)
sns.heatmap(iris_corr,annot=True,ax=axes[0])

sns.histplot(
    x = "total_bill",
    hue="smoker",
    data=tips,
    kde=True,
    multiple="stack",
    ax=axes[1]
)

sns.scatterplot(
    x="total_bill",
    y="tip",
    data=tips,
    hue="time",
    size="size",
    alpha=0.7,
    ax=axes[2]
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(
    x="day",
    y="total_bill",
    hue="sex",
    data=tips
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
smoker = tips[tips["smoker"]=="Yes"]

nonsmoker = tips[tips["smoker"]=="No"]

plt.pie(
    [len(smoker),len(nonsmoker)],
    labels= ["smoker","nonsmoker"],
    autopct="%1.1f%%",
    explode= [0.09,0]
)
# Out:
# ([<matplotlib.patches.Wedge at 0x794265ba68a0>,
#   <matplotlib.patches.Wedge at 0x794265b7e8d0>],
#  [Text(0.43407659283116934, 1.1080060972558246, 'smoker'),
#   Text(-0.4012473665774821, -1.024207279223613, 'nonsmoker')],
#  [Text(0.25169146979286283, 0.6424573168962343, '38.1%'),
#   Text(-0.21886219995135386, -0.5586585159401525, '61.9%')])
