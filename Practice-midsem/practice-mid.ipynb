# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'
df = pd.read_csv(url)
df

# %%
plt.plot(df["sepal_width"][:30])
plt.show()

# %%
plt.plot(df["sepal_length"][:50], linestyle="-",color="red",marker="s")

# %%
plt.plot(df["petal_length"][:50],linestyle="-", marker="o", color="green")
plt.xlim(1.2,5.2)
plt.ylim(1.2,5.2)
plt.xticks([1,1.5,2,2.5,3,3.5,4,4.5,5])
plt.yticks([1,1.5,2,2.5,3,3.5,4,4.5,5])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("This is a title ($cm$)")
plt.show()

# %%
import numpy as np
print(np.linspace(0,10,100))

# %%
x = np.arange(1,11,1)
y = x**2
plt.plot(x, color="green")
plt.plot(y,color="blue")
plt.annotate("Square function",xy=[6,50],xytext=[5,75],arrowprops=dict(facecolor="red",shrink=0))
plt.annotate("Constant function",xy=[6,10],xytext=[5,20],arrowprops=dict(facecolor="red",shrink=0))

# %%
df

# %%
fig,axes = plt.subplots(2,2,figsize=(10,12))

sc1 = axes[0,0].scatter(df['petal_length'],df["petal_width"], c=df["petal_length"], cmap="viridis")
plt.colorbar(sc1,ax=axes[0,0],label="Petal length")

sc2 = axes[0,1].scatter(df["sepal_length"],df["sepal_width"], c=df["sepal_length"])
plt.colorbar(sc2,ax=axes[0,1])

# %%
fig,axes = plt.subplots(2,2,figsize=(10,12))

sc1 = axes[0,0].scatter(df["sepal_length"],df["sepal_width"],c=df["petal_length"],cmap="viridis")
plt.colorbar(sc1,ax=axes[0,0],label="Petal Length (cm)")
axes[0,0].set_title("Sepal Length vs Sepal Width")
axes[0,0].set_xlim(3,7)
axes[0,0].set_ylim(3,5)
axes[0,0].set_xticks([3,3.5,4,4.5,5,5.5,6,6.5,7])
axes[0,0].set_yticks([3,3.5,4,4.5,5])
axes[0,0].annotate("Sepal Length (vs) Sepal Width",xy=(5.6,4.4),xytext=(4,4.7),arrowprops=dict(facecolor="red"))
axes[0,0].set_xlabel("Sepal Length")
axes[0,0].set_ylabel("Sepal Width")


sc2 = axes[0,1].plot(df["sepal_length"][:20],linestyle="-",color="red",marker="o")
axes[0,1].annotate("Peak",xy=(5,5.4),xytext=(5.9,5.7),arrowprops=dict(facecolor="green"))

plt.tight_layout()
plt.show()

# %%
from scipy.stats import gaussian_kde
import numpy as np

# %%
data = df["petal_length"]
kde = gaussian_kde(data)

x = np.linspace(data.min(),data.max(),100)

plt.plot(x,kde(x),color="green")
plt.show()

# %%
x = df["sepal_length"]
y = df["sepal_width"]

xy = np.vstack([x,y])
kde = gaussian_kde(xy)

xi,yi = np.mgrid[x.min():x.max():100j,y.min():y.max():100j]
zi = kde(np.vstack([xi.flatten(),yi.flatten()]))

plt.pcolormesh(xi,yi,zi.reshape(xi.shape),shading="auto",cmap="Blues")
plt.contour(xi,yi,zi.reshape(xi.shape),color="k")

plt.show()

# %%
x1 = np.array([1,3,5,7,9])
y1 = np.array([2,4,6,8,10])

plt.bar(x1,x1**2)
plt.bar(y1,y1**2)

for x,y in zip(x1,x1**2):
    plt.text(x,y+0.5,'%d' % y)

for x,y in zip(y1,y1**2):
    plt.text(x,y+0.5,'%d' % y)

# %%
x = ["A","B","C"]
y1 = [10,20,30]
y2 = [5,5,5]
y3 = [2,2,2]

plt.bar(x,y1,width=0.5)
plt.bar(x,y2,bottom=y1,width=0.5)
plt.bar(x,y3,bottom=np.add(y1,y2),width=0.5)

# %%
x1 = ["A","B","C"]
y1 = [10,20,30]
y2 = [15,35,25]
y3 = [32,22,12]

pos1 = np.arange(len(y1))
pos2 = [x+0.25 for x in pos1]
pos3 = [x+0.25 for x in pos2]
    
plt.bar(pos1,y1,width=0.25)
plt.bar(pos2,y2,width=0.25)
plt.bar(pos3,y3,width=0.25)

plt.xticks([x+0.25 for x in pos1],x1)

# %%
plt.scatter(np.random.random(10),np.random.random(10),c="blue",alpha=0.5,s=100)

# %%
plt.pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)

# %%
fig,axes = plt.subplots(2,3,figsize=(10,6))
axes[0,0].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[0,1].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[0,2].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[1,0].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[1,1].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)
axes[1,2].pie([45,90,60,20],labels=["A","B","C","D"],explode=[0,0,0,0.2],autopct="%1.1f",shadow=True)

# %%
import seaborn as sns

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x1 = np.linspace(0, 10, 1000)
y1 = np.sin(x1)

sns.set(rc={"axes.facecolor":"yellow","xtick.labelsize":14})

plt.style.use("ggplot")
sns.lineplot(x=x1, y=y1)
plt.xlim(0,10)
plt.yticks([-1,0,1])
plt.grid(True)
plt.show()

# %%
spotify = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/spotify.csv', index_col='Date')
spotify.sample(10)

# %%
sns.lineplot(data=spotify)
plt.rcParams["text.color"] = "black"

# %%
employment = pd.read_excel('https://github.com/dayanandv/Data-Science/raw/main/dataset/unemployment.xlsx')
employment.head()

# %%
#sns.set(rc={"axes.labelsize":24,"xtick.labelsize":20,"ytick.labelsize":20,"legend.fontsize":24,"legend.title_fontsize":24})
plt.figure(figsize=(30,15))
sns.lineplot(x="Period",y="Unemployed",hue="Gender",data=employment)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.random.normal(1,10,1000)
import seaborn as sns
sns.histplot(x,bins=30,kde=True)

# %%
from scipy.stats import gaussian_kde

# %%
url = 'https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'
df = pd.read_csv(url)
df

# %%
data = df["petal_length"]

x = np.linspace(data.min(),data.max(),100)
kde = gaussian_kde(data)

plt.plot(x,kde(x))

# %%
df = sns.load_dataset("iris")
df

# %%
data = df.corr(numeric_only=True)
sns.heatmap(data,center=0,annot=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
iris = sns.load_dataset("iris")
iris

# %%
sns.pairplot(
    vars=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    data=iris,
    hue="species"
)

# %%
iris_corr = iris.corr(numeric_only=True)
sns.heatmap(iris_corr,annot=True)

# %%
tips = sns.load_dataset("tips")
tips

# %%
sns.catplot(
    x="day",
    y="tip",
    hue="sex",
    data=tips,
    kind="box"
)

# %%
sns.histplot(
    x = "total_bill",
    hue="smoker",
    data=tips,
    kde=True,
    multiple="stack"
)

# %%
sns.scatterplot(
    x="total_bill",
    y="tip",
    data=tips,
    hue="time",
    size="size",
    alpha=0.7
)

# %%
fig,axes = plt.subplots(1,3,figsize=(30,9))

iris_corr = iris.corr(numeric_only=True)
sns.heatmap(iris_corr,annot=True,ax=axes[0])

sns.histplot(
    x = "total_bill",
    hue="smoker",
    data=tips,
    kde=True,
    multiple="stack",
    ax=axes[1]
)

sns.scatterplot(
    x="total_bill",
    y="tip",
    data=tips,
    hue="time",
    size="size",
    alpha=0.7,
    ax=axes[2]
)

# %%
tips

# %%
sns.barplot(
    x="day",
    y="total_bill",
    hue="sex",
    data=tips
)

# %%
smoker = tips[tips["smoker"]=="Yes"]

nonsmoker = tips[tips["smoker"]=="No"]

plt.pie(
    [len(smoker),len(nonsmoker)],
    labels= ["smoker","nonsmoker"],
    autopct="%1.1f%%",
    explode= [0.09,0]
)

# %%
pip install basemap

# %%
from mpl_toolkits.basemap import Basemap

# %%
m = Basemap(
    llcrnrlat=5,
    llcrnrlon=68,
    urcrnrlat=38,
    urcrnrlon=98,
    projection="merc"
)
m.drawcoastlines()
m.drawrivers(color="lightblue")
m.drawcounties()
m.fillcontinents(color="green",lake_color="blue")
m.drawmapboundary(fill_color='aqua')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))

m = Basemap(
    projection="ortho",
    lat_0=20,
    lon_0=80
)


m.drawcoastlines()
m.drawstates()
m.fillcontinents(color="lightgreen",lake_color="aqua")
m.drawmapboundary(fill_color="aqua")

cities = {
    "Delhi" : (28.6,77.2),
    "Cairo" : (30.0,31.2),
    "Moscow" : (55.7,37.6),
    "Bankok" : (13.7,100.5),
    "Nairobi" : (-1.3,36.8)
}

for city,coord in cities.items():
    lat,long = coord
    x,y = m(long,lat)
    plt.plot(x,y,marker="o",color="black")
    plt.text(x,y,city,color="red")

plt.tight_layout()

# %%
plt.figure(figsize=(20,10))
m = Basemap(
    projection="robin",
    lat_0=0,
    lon_0=0
)
m.drawcoastlines()
m.fillcontinents(color="brown",lake_color="aqua")
m.drawmapboundary(fill_color="aqua")

cities = {
    "New York": (40.7, -74.0),
    "Tokyo": (35.7, 139.7),
    "Sydney": (-33.9, 151.2)
}

for city,coord in cities.items():
    lat,lon = coord
    x,y = m(lon,lat)
    plt.plot(x,y,marker="o",color="green")
    plt.text(x,y,city,color="green")

# %%
import numpy as np
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)

X,Y = np.meshgrid(x,y)

fig = plt.figure(figsize=(10,12))
ax = fig.add_subplot(111,projection="3d")
Z = np.sin(np.sqrt(X**2 + Y**2)) / (np.sqrt(X**2 + Y**2) + 1e-8)

surface = ax.plot_surface(X,Y,Z,cmap="viridis")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)

X,Y = np.meshgrid(x,y)

Z = np.sin(X)*np.cos(Y) + (0.5*np.sin(2*X)*np.cos(2*Y))

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111,projection="3d")

surface1 = ax.plot_surface(X,Y,Z,cmap="viridis")

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111,projection="3d")
surface2 = ax.plot_wireframe(X,Y,Z)

# %%
import matplotlib.tri as tri

# %%
x = np.random.uniform(-2,2,100)
y = np.random.uniform(-2,2,100)
z = np.sin(x) * np.cos(y) + 0.1 * np.random.normal(0, 1, 100)

triang = tri.Triangulation(x,y)

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111,projection="3d")

surface3 = ax.plot_trisurf(x,y,z,triangles=triang.triangles)

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)

X,Y = np.meshgrid(x,y)

Z = np.sin(np.sqrt(X**2 + Y**2)) + 0.3*np.cos(2*X)*np.sin(2*Y)

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111,projection="3d")

surface4 = ax.plot_surface(X,Y,Z,cmap="viridis")

contourz = ax.contour(X,Y,Z,zdir="z")
contourx = ax.contour(X,Y,Z,zdir="x")
contoury = ax.contour(X,Y,Z,zdir="y")

ax.set_xlabel("X")
ax.set_ylabel("Y")

fig.colorbar(surface4,ax=ax)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#1 - Pie chart: Show the percentage of time (Lunch vs Dinner). Explode the larger slice.

# %%
lunch = tips[tips["time"]=="Lunch"]
dinner = tips[tips["time"]=="Dinner"]
plt.pie(
    x = [len(lunch),len(dinner)],
    labels=["Lunch","Dinner"],
    explode= [0,0.1],
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b1778ea4a40>,
# ...
#  [Text(0.7046525082360607, 0.8446684809063427, 'Lunch'),
#   Text(-0.7687119134395944, -0.9214564526531016, 'Dinner')])

# %%
sns.barplot(
    x="day",
    y="total_bill",
    data=tips,
    ci=None,
    hue="day"
)
# Out:
# /tmp/ipykernel_33680/2636638121.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips1 = tips[["day","sex"]]
tips1 = tips1.value_counts().unstack()

# %%
tips1.plot(
    kind="bar",
    stacked=True
)
# Out:
# <Axes: xlabel='day'>

# %%
x = [1,2,3,4,5]
y1 = [2,2,2,2,2]
y2 = [3,3,5,3,3]
y3 = [5,5,5,5,5]

pos1 = np.arange(len(x))
pos2 = [x+0.25 for x in pos1]
pos3 = [x+0.25 for x in pos2]


plt.bar(pos1,y1,width=0.25)
plt.bar(pos2,y2,width=0.25)
plt.bar(pos3,y3,width=0.25)

plt.xticks([x+0.25 for x in pos1],x)
# Out:
# ([<matplotlib.axis.XTick at 0x7b176d607380>,
# ...
#  [Text(0.25, 0, '1'),
#   Text(1.25, 0, '2'),
#   Text(2.25, 0, '3'),
#   Text(3.25, 0, '4'),
#   Text(4.25, 0, '5')])

# %%
dinner,lunch = tips["time"].value_counts()

# %%
plt.pie([dinner,lunch],labels=["Dinner","Lunch"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7b176d16bcb0>,
# ...
#  [Text(-0.7046524291524868, 0.8446685468806683, 'Dinner'),
#   Text(0.7046523500689068, -0.8446686128549864, 'Lunch')])

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips2 = tips["total_bill"].sum()

# %%
tips2
# Out:
# 4827.77

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(
    y="tip",
    x="day",
    hue="sex",
    data=tips
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
lunch = len(tips["time"]=="Lunch")
dinner = len(tips["time"]=="Dinner")
plt.pie([lunch+10,dinner],labels=["Lunch","Dinner"],autopct="%1.1f%%",shadow=True,explode=[0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c32f83911c0>,
# ...
#  [Text(-0.03469056302144898, 1.099452847937216, 'Lunch'),
#   Text(0.03784425056885355, -1.1994031068405993, 'Dinner')],
#  [Text(-0.018922125284426713, 0.5997015534202996, '51.0%'),
#   Text(0.022075812831831236, -0.6996518123236829, '49.0%')])

# %%
new = tips.groupby("day")["sex"].value_counts().unstack()
# Out:
# /tmp/ipykernel_5552/2978117416.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new = tips.groupby("day")["sex"].value_counts().unstack()

# %%
new.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='day'>

# %%
sns.boxplot(
    x="day",
    y="tip",
    hue="sex",
    data=tips
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(
    x="time",
    y="total_bill",
    hue="sex",
    data=tips,
)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(
    vars=["total_bill","tip","size"],
    hue="sex",
    data=tips
)

# %%
sns.scatterplot(
    x="total_bill",
    y="tip",
    data=tips
)
plt.annotate("Largest Tip",xy=[50,10],xytext=[30,9.5],arrowprops=dict(facecolor="blue"))
# Out:
# Text(30, 9.5, 'Largest Tip')

# %%
import matplotlib.tri as tri

# %%
x = tips["size"]
y = tips["total_bill"]
z = tips["tip"]

triang = tri.Triangulation(x,y)

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111,projection = "3d")

surface1 = ax.plot_trisurf(x,y,z,triangles=triang.triangles,cmap="terrain")

fig.colorbar(surface1,ax=ax)

# %%
from scipy.stats import gaussian_kde

# %%
plt.figure(figsize=(12,10))
m = Basemap(
    projection="cyl",
    llcrnrlat=5, urcrnrlat=37,llcrnrlon=68, urcrnrlon=97,
)

m.drawcoastlines()
m.drawcounties()
m.drawstates()
m.fillcontinents(color="lightgreen",lake_color="aqua")
m.drawmapboundary(fill_color="aqua")
m.drawrivers()

cities = {
    "Delhi": (28.61, 77.20),
    "Mumbai": (19.07, 72.87),
    "Chennai": (13.08, 80.27),
    "Kolkata": (22.57, 88.36),
    "Bangalore": (12.97, 77.59),
    "Hyderabad": (17.38, 78.49)
}


for city,coord in cities.items():
    lat,lon = coord
    x,y = m(lon,lat)
    plt.plot(x,y,marker="o",color="black")
    plt.text(x,y,city,color="black")

# %%
tips_corr = tips.corr(numeric_only=True)
sns.heatmap(
    tips_corr,
    annot=True
)
# Out:
# <Axes: >
