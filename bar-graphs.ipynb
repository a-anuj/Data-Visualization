# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])

# %%
plt.figure(figsize=(7,7))
plt.bar(num1,num1**2,width=0.2,color="blue")
plt.bar(num2,num2**2,width=0.2,color="red")
plt.show()
