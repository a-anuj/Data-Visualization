# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("practiceCSV.csv")
print(df)
# Out:
#     Name  Age Department  Salary
# 0  Mehta   22         IT   60000
# 1  Priya   24         HR   52000
# 2  Rahul   23    Finance   58000
# 3  Sneha   25         IT   61000
# 4   Amit   22  Marketing   50000
# 5  Meera   26    Finance   62000
# 6  Karan   24         HR   54000
# 7   Isha   23  Marketing   51000

# %%
plt.bar(df["Department"],df["Salary"],width=0.3)
# Out:
# <BarContainer object of 8 artists>

# %%
grouped_value = df.groupby("Department")["Salary"].mean()
grouped_value.plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>
